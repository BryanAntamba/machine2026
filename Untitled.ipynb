# %% [markdown]
# <img src="img/itq.png"> <br>
# # Introduccion a Python
# <img src="img/img1.png"> </br>
# **Nombre:** *Bryan Antamba*
#
# **Fecha:**  *07/01/2026*

# %%
#Comentario de python
print("Esto es python")
# Out:
# Esto es python
